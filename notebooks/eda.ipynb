# %%
import pandas as pd
import matplotlib.pyplot as plt

import sys
import os
sys.path.append(os.path.abspath(os.path.join(os.getcwd(), '../src')))
sys.path.append(os.path.abspath(os.path.join(os.getcwd(), '../scripts')))
from eda.eda import EDA
from data_convertort.convert_to_csv import TxtToCSVConverter

# %%
converter = TxtToCSVConverter('../data/MachineLearningRating_v3.txt', '../data/MachineLearningRating_v3.csv')
converter.convert()
# Out:
# Output file already exists: ../data/MachineLearningRating_v3.csv. Conversion skipped.

# %%
# Load the data
data = pd.read_csv('../data/MachineLearningRating_v3.csv')
# Out:
# C:\Users\sefuwan.feysa\AppData\Local\Temp\ipykernel_22316\2018916717.py:2: DtypeWarning: Columns (32,37) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv('../data/MachineLearningRating_v3.csv')

# %%
# Initialize the EDA class
eda = EDA(data)

# Perform EDA tasks
print("Data Summary:\n", eda.data_summary())
# Out:
# Data Summary:
#         UnderwrittenCoverID      PolicyID    PostalCode        mmcode  \
# count         1.000098e+06  1.000098e+06  1.000098e+06  9.995460e+05
# mean          1.048175e+05  7.956682e+03  3.020601e+03  5.487770e+07
# std           6.329371e+04  5.290039e+03  2.649854e+03  1.360381e+07
# min           1.000000e+00  1.400000e+01  1.000000e+00  4.041200e+06
# 25%           5.514300e+04  4.500000e+03  8.270000e+02  6.005692e+07
# 50%           9.408300e+04  7.071000e+03  2.000000e+03  6.005842e+07
# 75%           1.391900e+05  1.107700e+04  4.180000e+03  6.005842e+07
# max           3.011750e+05  2.324600e+04  9.870000e+03  6.506535e+07
#
#        RegistrationYear      Cylinders  cubiccapacity      kilowatts  \
# count      1.000098e+06  999546.000000  999546.000000  999546.000000
# mean       2.010225e+03       4.046642    2466.743258      97.207919
# std        3.261391e+00       0.294020     442.800640      19.393256
# min        1.987000e+03       0.000000       0.000000       0.000000
# 25%        2.008000e+03       4.000000    2237.000000      75.000000
# 50%        2.011000e+03       4.000000    2694.000000     111.000000
# 75%        2.013000e+03       4.000000    2694.000000     111.000000
# max        2.015000e+03      10.000000   12880.000000     309.000000
#
#        NumberOfDoors  CustomValueEstimate  NumberOfVehiclesInFleet  \
# count  999546.000000         2.204560e+05                      0.0
# mean        4.019250         2.255311e+05                      NaN
# std         0.468314         5.645157e+05                      NaN
# min         0.000000         2.000000e+04                      NaN
# 25%         4.000000         1.350000e+05                      NaN
# 50%         4.000000         2.200000e+05                      NaN
# 75%         4.000000         2.800000e+05                      NaN
# max         6.000000         2.655000e+07                      NaN
#
#          SumInsured  CalculatedPremiumPerTerm  TotalPremium   TotalClaims
# count  1.000098e+06              1.000098e+06  1.000098e+06  1.000098e+06
# mean   6.041727e+05              1.178757e+02  6.190550e+01  6.486119e+01
# std    1.508332e+06              3.997017e+02  2.302845e+02  2.384075e+03
# min    1.000000e-02              0.000000e+00 -7.825768e+02 -1.200241e+04
# 25%    5.000000e+03              3.224800e+00  0.000000e+00  0.000000e+00
# 50%    7.500000e+03              8.436900e+00  2.178333e+00  0.000000e+00
# 75%    2.500000e+05              9.000000e+01  2.192982e+01  0.000000e+00
# max    1.263620e+07              7.442217e+04  6.528260e+04  3.930921e+05

# %%
print("Data Structure:\n", eda.data_structure())
# Out:
# Data Structure:
#  UnderwrittenCoverID           int64
# PolicyID                      int64
# TransactionMonth             object
# IsVATRegistered                bool
# Citizenship                  object
# LegalType                    object
# Title                        object
# Language                     object
# Bank                         object
# AccountType                  object
# MaritalStatus                object
# Gender                       object
# Country                      object
# Province                     object
# PostalCode                    int64
# MainCrestaZone               object
# SubCrestaZone                object
# ItemType                     object
# mmcode                      float64
# VehicleType                  object
# RegistrationYear              int64
# make                         object
# Model                        object
# Cylinders                   float64
# cubiccapacity               float64
# kilowatts                   float64
# bodytype                     object
# NumberOfDoors               float64
# VehicleIntroDate             object
# CustomValueEstimate         float64
# AlarmImmobiliser             object
# TrackingDevice               object
# CapitalOutstanding           object
# NewVehicle                   object
# WrittenOff                   object
# Rebuilt                      object
# Converted                    object
# CrossBorder                  object
# NumberOfVehiclesInFleet     float64
# SumInsured                  float64
# TermFrequency                object
# CalculatedPremiumPerTerm    float64
# ExcessSelected               object
# CoverCategory                object
# CoverType                    object
# CoverGroup                   object
# Section                      object
# Product                      object
# StatutoryClass               object
# StatutoryRiskType            object
# TotalPremium                float64
# TotalClaims                 float64
# dtype: object

# %%
print("Missing Values:\n", eda.check_missing_values())
# Out:
# Missing Values:
#                           Missing Values  Percentage
# NumberOfVehiclesInFleet         1000098  100.000000
# CrossBorder                      999400   99.930207
# CustomValueEstimate              779642   77.956560
# WrittenOff                       641901   64.183810
# Converted                        641901   64.183810
# Rebuilt                          641901   64.183810
# NewVehicle                       153295   15.327998
# Bank                             145961   14.594670
# AccountType                       40232    4.022806
# Gender                             9536    0.953507
# MaritalStatus                      8259    0.825819
# mmcode                              552    0.055195
# VehicleType                         552    0.055195
# make                                552    0.055195
# VehicleIntroDate                    552    0.055195
# NumberOfDoors                       552    0.055195
# bodytype                            552    0.055195
# kilowatts                           552    0.055195
# cubiccapacity                       552    0.055195
# Cylinders                           552    0.055195
# Model                               552    0.055195
# CapitalOutstanding                    2    0.000200

# %%
# Perform univariate analysis on a specific column (e.g., 'TotalPremium')
print("Univariate Analysis on 'TotalPremium':")
eda.univariate_analysis('TotalPremium')
plt.show()  # Show the histogram
# Out:
# Univariate Analysis on 'TotalPremium':

# %%
# Perform bivariate analysis between 'TotalPremium' and 'TotalClaims'
print("Bivariate Analysis between 'TotalPremium' and 'TotalClaims':")
eda.bivariate_analysis('TotalPremium', 'TotalClaims')
plt.show()
# Out:
# Bivariate Analysis between 'TotalPremium' and 'TotalClaims':

# %%
# Plot the correlation matrix
print("Correlation Matrix:")
eda.plot_correlation_matrix()
# Out:
# Correlation Matrix:

# %%
# Detect outliers in 'TotalPremium'
print("Outlier Detection in 'TotalPremium':")
eda.outlier_detection('TotalPremium')
# Out:
# Outlier Detection in 'TotalPremium':

# %%
# Parse the date columns and extract features
eda.parse_dates()
print("Dates parsed and features extracted")
# Out:
# Dates parsed and features extracted

# %%
# Encode categorical features
eda.encode_categorical()
print("Categorical features encoded")
# Out:
# Categorical features encoded

# %%
# Analyze the ratio between Premium and Claims
print("Premium to Claims Ratio Analysis:")
print(eda.premium_claim_analysis())
# Out:
# Premium to Claims Ratio Analysis:
#        TotalPremium   TotalClaims  ClaimToPremiumRatio
# count  1.000098e+06  1.000098e+06             618614.0
# mean   6.190550e+01  6.486119e+01                  NaN
# std    2.302845e+02  2.384075e+03                  NaN
# min   -7.825768e+02 -1.200241e+04                 -inf
# 25%    0.000000e+00  0.000000e+00                  0.0
# 50%    2.178333e+00  0.000000e+00                  0.0
# 75%    2.192982e+01  0.000000e+00                  0.0
# max    6.528260e+04  3.930921e+05                  inf
# d:\tutorial\10x\tasks\task_3\insurance-data-analytics\.winenv\Lib\site-packages\numpy\_core\_methods.py:53: RuntimeWarning: invalid value encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)

# %%
# Group by 'VehicleType' and analyze statistics
print("Group by 'VehicleType' Analysis:")
print(eda.group_by_analysis('VehicleType'))
# Out:
# Group by 'VehicleType' Analysis:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[14], line 3
#       1 # Group by 'VehicleType' and analyze statistics
#       2 print("Group by 'VehicleType' Analysis:")
# ----> 3 print(eda.group_by_analysis('VehicleType'))
#
# File d:\tutorial\10x\tasks\task_3\insurance-data-analytics\src\eda\eda.py:114, in EDA.group_by_analysis(self, group_column)
#     112 # Check if the column exists
#     113 if group_column not in self.data.columns:
# --> 114         raise KeyError(f"Column '{group_column}' not found in the dataset. Available columns are: {list(self.data.columns)}")
#     115 # Check if the required columns for analysis exist
#     116 required_columns = ['TotalPremium', 'TotalClaims']
#
# KeyError: "Column 'VehicleType' not found in the dataset. Available columns are: ['UnderwrittenCoverID', 'PolicyID', 'TransactionMonth', 'IsVATRegistered', 'Citizenship', 'Title', 'Language', 'Bank', 'AccountType', 'MaritalStatus', 'Gender', 'Country', 'Province', 'PostalCode', 'MainCrestaZone', 'SubCrestaZone', 'ItemType', 'mmcode', 'RegistrationYear', 'Cylinders', 'cubiccapacity', 'kilowatts', 'bodytype', 'NumberOfDoors', 'VehicleIntroDate', 'CustomValueEstimate', 'AlarmImmobiliser', 'TrackingDevice', 'CapitalOutstanding', 'NewVehicle', 'WrittenOff', 'Rebuilt', 'Converted', 'CrossBorder', 'NumberOfVehiclesInFleet', 'SumInsured', 'TermFrequency', 'CalculatedPremiumPerTerm', 'ExcessSelected', 'CoverCategory', 'CoverGroup', 'Section', 'Product', 'StatutoryClass', 'StatutoryRiskType', 'TotalPremium', 'TotalClaims', 'TransactionYear', 'TransactionMonthOnly', 'LegalType_Close Corporation', 'LegalType_Individual', 'LegalType_Partnership', 'LegalType_Private company', 'LegalType_Public company', 'LegalType_Sole proprieter', 'VehicleType_Bus', 'VehicleType_Heavy Commercial', 'VehicleType_Light Commercial', 'VehicleType_Medium Commercial', 'VehicleType_Passenger Vehicle', 'CoverType_Accidental Death', 'CoverType_Asset Value Preserver', 'CoverType_Baggage/Luggage', 'CoverType_Basic Excess Waiver', 'CoverType_Cash Takings', 'CoverType_Cleaning and Removal of Accident Debris', 'CoverType_Credit Protection', 'CoverType_Deposit Cover', 'CoverType_Emergency Charges', 'CoverType_Factory Fitted Sound and Other Electronic Equipment', 'CoverType_Fire and Theft', 'CoverType_Income Protector', 'CoverType_Keys and Alarms', 'CoverType_Own Damage', 'CoverType_Passenger Liability', 'CoverType_Roadside Assistance', 'CoverType_Signage and Vehicle Wraps', 'CoverType_Standalone passenger liability', 'CoverType_Third Party', 'CoverType_Third Party Only', 'CoverType_Trailer', 'CoverType_Windscreen', 'make_AUDI', 'make_B.A.W', 'make_BMW', 'make_C.A.M', 'make_CHERY                              ', 'make_CHEVROLET', 'make_CITROEN                            ', 'make_CMC', 'make_DAIHATSU', 'make_FIAT', 'make_FORD', 'make_FORD                               ', 'make_FOTON', 'make_GEELY                              ', 'make_GOLDEN JOURNEY', 'make_HINO', 'make_HONDA', 'make_HUMMER', 'make_HYUNDAI', 'make_IVECO', 'make_JINBEI', 'make_JINBEI                             ', 'make_JMC                                ', 'make_KIA', 'make_LEXUS', 'make_MAHINDRA', 'make_MARCOPOLO', 'make_MAZDA', 'make_MERCEDES-BENZ', 'make_MERCEDES-BENZ                      ', 'make_MITSUBISHI', 'make_NISSAN', 'make_NISSAN/DATSUN                      ', 'make_OPEL', 'make_PEUGEOT', 'make_POLARSUN', 'make_PROTON', 'make_RENAULT', 'make_SAIC', 'make_SCANIA', 'make_SUZUKI                             ', 'make_TATA', 'make_TOYOTA', 'make_TOYOTA                             ', 'make_VOLKSWAGEN', 'make_VOLVO', 'Model_0305 M BAR B/S CCL', 'Model_115 VITO 2.2 CDI CREW CAB F/C P/V', 'Model_13-206 F/C C/C', 'Model_1400 CHAMP (B01) P/U S/C', 'Model_3 1.6 DYNAMIC', 'Model_3 2.0 INDIVIDUAL', 'Model_316i (E36)', 'Model_316i (F30)', 'Model_316i A/T (F30)', 'Model_318iS (E36)', 'Model_320d (E90)', 'Model_320d A/T (E90)', 'Model_320d START (E90)', 'Model_320i (E36)', 'Model_320i (E90)', 'Model_320i (F30)', 'Model_320i A/T (E90)', 'Model_320i START (E90)', 'Model_323 130 STING', 'Model_325i (E46)F/L', 'Model_328i (F30)', 'Model_330i (E90)', 'Model_35 S13V 7M F/C P/V', 'Model_35 S13V 8 F/C P/V', 'Model_35 S13V 9M F/C P/V', 'Model_35S12V10 F/C P/V', 'Model_35S12V12 F/C P/V', 'Model_35S12V8 F/C P/V', 'Model_35S15C CAMPER P/V', 'Model_40 C11CC F/C C/C', 'Model_5 2.0L ACTIVE', 'Model_50 C13 F/C C/C', 'Model_50 C13D F/C D/C', 'Model_50 C13V 15M F/C P/V', 'Model_50 C15V 15 F/C P/V', 'Model_50C15 F/C C/C', 'Model_50C15V12 F/C P/V', 'Model_50C15V15 F/C P/V', 'Model_523i A/T (E60)', 'Model_525i (E60)', 'Model_626 200 e', 'Model_A4 1.8T AMBITION (B8)', 'Model_A4 1.8T AMBITION MULTITRONIC (B8)', 'Model_A4 1.8T ATTRACTION ( ...

# %%
# Analyze SumInsured, CustomValueEstimate, and TotalPremium correlation
print("SumInsured and Premium Correlation:")
print(eda.sum_insured_analysis())

# %%
# Filter outliers for 'TotalPremium'
filtered_data = eda.filter_outliers('TotalPremium')
print("Filtered Data (Outliers removed):")
print(filtered_data.head())

# %%
# Perform geographic analysis
print("Geographic Analysis by Province:")
eda.geographic_analysis()
plt.show()
